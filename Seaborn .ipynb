# %% [markdown]
# # Visualizing statistical relationships
#
# Statistical analysis is a process of understanding how variables in a dataset relate to each other and how those relationships depend on other variables. Visualization can be a core component of this process because, when data are visualized properly, the human visual system can see trends and patterns that indicate a relationship.
#
# ### 1. Numerical Data Ploting
# - relplot()
# - scatterplot()
# - lineplot()
#
# ### 2. Categorical Data Ploting
# - catplot()
# - boxplot()
# - stripplot()
# - swarmplot()
# - etc...
#
# ### 3. Visualizing Distribution of the Data
# - distplot()
# - kdeplot()
# - jointplot()
# - rugplot()
#
# ### 4. Linear Regression and Relationship
# - regplot()
# - lmplot()
#
# ### 5. Controlling Ploted Figure Aesthetics
# - figure styling
# - axes styling
# - color palettes
# - etc..

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Numerical Data Ploting:
# ### i). relplot()

# %%
# Loading tips dataset.

tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Suppose we want to find out 'size' column of this tips dataset:

tips['size']
# Out:
# 0      2
# 1      3
# 2      3
# 3      2
# 4      4
#       ..
# 239    3
# 240    2
# 241    2
# 242    2
# 243    2
# Name: size, Length: 244, dtype: int64

# %%
## Plotting the graph to show the relationship b/w total_bill column and tip column:

sns.relplot(x='total_bill',y='tip',data=tips)

# %%
## we can see even if it is facetGrid plot but in background we don't see any grids ie. just a white background.
## Therefore we use style parameter and set style='darkgrid'(say):

sns.set(style='darkgrid')
sns.relplot(x='total_bill',y='tip',data=tips)

# %% [markdown]
# ###
# By just seeing the plot ie total bill and tip what conclusion we got:
# 1. As total bill increasing tip is also increasing
# 2. Pattern actually is increasing linearly.(When we will be doing linear regression at that time it will be useful)

# %%
## In tips dataset we still have lot of categorical features ie.( not in numeric form like sex,smoker,day,time.)
# If we want to plot wrt categorical features say we want to draw for smoker column:

## In order to find out how many smokers we can write it as:

tips['smoker'].value_counts()


# It says that 93 people smoke.
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %% [markdown]
# ### hue parameter:
#
# 1. In order to plot this smokers and non smokers too, what we can do is
# 2. There is a parameter called hue, This hue will always take categorical features.
# 3. w.r.t hue=smoker, there will be Yes or No points in the plot (yes in blue color and No in orange color)

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, hue = 'smoker')

# %%
# style parameter : In this we can pass another categorical feature let's say we are writing style='time'
# the round shaped is lunch time and cross one is Dinner time.


sns.relplot(x = 'total_bill', y = 'tip', data = tips, hue = 'smoker',style='time')

# %%
# If you want style =sex, you can do this also.

sns.relplot(x = 'total_bill', y = 'tip', data = tips, hue = 'smoker',style='sex')

# %%
tips['size'].value_counts()

## means there are total of 1,2,3,4,5,6 total 6 types.
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 6      4
# 1      4
# Name: size, dtype: int64

# %%
## you can also set style=size (ie. size column is set in style parameter)

sns.relplot(x = 'total_bill', y = 'tip', data = tips, hue = 'smoker',style='size')

# %%
## We can also put numeric values or features in hue parameter: 
## As here we are setting hue='size'

sns.relplot(x = 'total_bill', y = 'tip', hue = 'size', data = tips)

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips,hue = 'smoker', style = 'time', size = 'size')

# %%
from numpy.random import randn

# %%
df = pd.DataFrame(dict(time = np.arange(500), value = randn(500).cumsum()))

# %%
df.head()
# Out:
#    time     value
# 0     0 -0.199428
# 1     1  0.159823
# 2     2  0.515356
# 3     3  0.229338
# 4     4 -0.067265

# %%
sns.relplot(x = 'time', y = 'value', kind = 'line', data = df, sort = True)

# %%
# Loading fmri dataset
# fmri is some signal processing dataset.

fmri = sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
# If we want to plot relationship plot b/w timepoint and signal:

sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri)

# %%
# The plot will create in such a way that the shadow thing that entire is confidence interval(ci)
# And the entire data that is plotted in line is basically based on standard deviation(sd).

sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri, ci = 'sd')

# %%
## passing hue parameter as 'event' :

sns.relplot(x = 'timepoint', y = 'signal', hue = 'event', kind = 'line', data = fmri)

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
# hue set as region:

sns.relplot(x = 'timepoint', y = 'signal', hue = 'region', style = 'event', kind = 'line', data = fmri)

# %%
# set : marker=true

sns.relplot(x = 'timepoint', y = 'signal', hue = 'region', style = 'event', kind = 'line', data = fmri, markers = True, dashes = False)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### col parameter:
#
# 1. col parameter only works when we assign categorical feature, if any numeric feature like ('size') is given then it will give error
# 2. If I want to use the same column for different graphs then we can set col parameter in relplot()
# 3. It will not work for integer columns.

# %%
tips['time'].value_counts()

## Since only two types of time ie. Dinner and lunch therefore two graphs will be plotted if we set col='time'
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'time', data = tips)

# %%
# using day as col ie. set col=day:

tips['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
# as col='day' means here are total 4 values.
# therfore 4 graphs will be plotted for each day found above.

sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'day', data = tips)

# %% [markdown]
# ### ii) Scatter Plot:

# %%
sns.scatterplot(x = 'total_bill', y = 'tip', data = tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# we can use hue parameter:

sns.scatterplot(x = 'total_bill', y = 'tip', data = tips,hue='sex')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### iii) lineplot:

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(x = 'timepoint', y  = 'signal', style = 'event', hue = 'region', data = fmri, markers = True, ci = 68, err_style='bars')
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
sns.scatterplot(x = 'total_bill', y = 'tip', data = tips, hue = 'smoker', size = 'size', style = 'time')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(x = 'sepal_length', y = 'petal_length', data = iris)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.scatterplot(x = iris['sepal_length'], y = iris['petal_length'])
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# ## 2. Categorical Data Ploting
# - catplot()
# - boxplot()
# - stripplot()
# - swarmplot()
# - etc...

# %%
import seaborn as sns

tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ### i) catplot()
# * This function provides access to several axes-level functions that show the relationship between a numerical and one or more categorical variables using one of several visual representations.

# %%
# To check the data types of each colmn(Features)

tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
# We are giving x as categorical parameter and y as numerical data type. Performing on the whole tips dataset ie. 3rd parameter.
# We can aslo convert this Int64 into category dtype.
sns.catplot(x = 'day', y = 'total_bill', data = tips)

# %%
sns.catplot(y = 'day', x = 'total_bill', data = tips)

# %%
# Jitter=False means we don't want the distribution of points in scattered form, we want it in sibgle line format:

sns.catplot(x = 'day', y = 'total_bill', data = tips, jitter = False)

# %% [markdown]
# ### Kind parameter:
# * This parameter includes many formatting of graphs such as:
# * kind : str, optional
#     The kind of plot to draw, corresponds to the name of a categorical
#     axes-level plotting function. Options are: "strip", "swarm", "box", "violin",
#     "boxen", "point", "bar", or "count".
# * By default kind=strip.

# %%
# kind=strip
sns.catplot(x = 'day', y = 'tip', data = tips, kind = 'strip', hue = 'size')

# %%
# kind=swarm:

sns.catplot(x = 'day', y = 'tip', data = tips, kind = 'swarm', hue = 'size')

# %%
# kind=box

sns.catplot(x = 'day', y = 'tip', data = tips, kind = 'box', hue = 'size')

# %%
# kind=violin:

sns.catplot(x = 'day', y = 'tip', data = tips, kind = 'violin', hue = 'size')

# %%
# kind=boxen:

sns.catplot(x = 'day', y = 'tip', data = tips, kind = 'boxen', hue = 'size')

# %%
# kind=point:

sns.catplot(x = 'day', y = 'tip', data = tips, kind = 'point', hue = 'size')

# %%
# kind=bar:

sns.catplot(x = 'day', y = 'tip', data = tips, kind = 'bar', hue = 'size')

# %%
## Use of 'order' parameter:
#order, hue_order : lists of strings, optional Order to plot the categorical levels in, otherwise the levels are inferred from the data objects.


sns.catplot(x = 'smoker', y = 'tip', data = tips, order= ['No', 'Yes'])

# %%
# If you don't want to add order by manually then write like below code, by default order will be taken:

sns.catplot(x = 'smoker', y = 'tip', data = tips)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
## Dodge parameter:

# %%
# Boxes are in combined form if dodge=False
sns.catplot(x = 'day', y = 'total_bill', kind = 'box', data = tips, hue = 'sex', dodge = False)

# %%
# Boxes are in separate form if dodge=True
sns.catplot(x = 'day', y = 'total_bill', kind = 'box', data = tips, hue = 'sex', dodge = True)

## Lets understand this graph like where it is used:
# Suppose A stakeholder or Hotel manger has this graph he can easily understand that total bill paid by both male & Female
# is high on weekends So he can make some offer availavle for those 2 days and make more money
# Suppose If I want to give offers to male then I will do it for Friday
# Bcs on friday there are lot payments done by male compared to female.
# So, These kind of use cases where stakeholder require some relevant data to make some decision.

# %%
## Loading Diamond dataSet:

# %%
diamonds = sns.load_dataset('diamonds')
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
# Sorting the dataset based on the color:
diamonds.sort_values('color')
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
# 7817    1.00  Very Good     D     SI2   63.5   59.0   4295  6.35  6.32  4.02
# 7816    1.00       Good     D     SI2   57.8   58.0   4295  6.61  6.55  3.80
# 7815    1.00  Very Good     D     SI2   61.5   63.0   4295  6.32  6.27  3.87
# 7809    0.56      Ideal     D      IF   61.9   57.0   4293  5.28  5.31  3.28
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 4861    1.00    Premium     J     SI1   60.8   58.0   3712  6.39  6.44  3.90
# 18421   1.52      Ideal     J     SI1   61.9   57.0   7491  7.37  7.33  4.55
# 18423   1.50  Very Good     J     VS2   62.6   58.0   7492  7.25  7.29  4.55
# 42108   0.65      Ideal     J     SI1   61.4   55.0   1276  5.58  5.62  3.44
# 14123   1.30      Ideal     J     SI1   61.5   55.0   5728  7.03  7.06  4.33
#
# [53940 rows x 10 columns]

# %%
# Now Let's execute this code:

sns.catplot(x = 'color', y = 'price', kind = 'boxen', data = diamonds.sort_values('color'))

# %% [markdown]
# * So, What Information can we get with above plot:
# 1. We can see the J color has highest median also the other values are also high as compare to different colors
# 2. So, Probably we will go to buy the J color Diamond.

# %%
sns.catplot(x = 'day', y = 'total_bill', kind = 'boxen', data = tips)

# %%
# Violin Plot:

# %%
sns.catplot(x = 'total_bill', y = 'day', hue = 'sex', kind = 'violin', data = tips, split = True,)

# %% [markdown]
# ## Combining catplot in swarmplot:
#
#
# ### Swarmplot:Draw a categorical scatterplot with non-overlapping points.
#
# * This function is similar to :func:`stripplot`, but the points are adjusted
# * (only along the categorical axis) so that they don't overlap. This gives a better representation of the distribution of values, but it does not scale well to large numbers of observations. This style of plot is sometimes called a "beeswarm".

# %%
g = sns.catplot(x = 'day', y = 'total_bill', kind = 'violin', inner = None, data = tips)
sns.swarmplot(x = 'day', y = 'total_bill', color = 'k', size = 3, data = tips, ax = g.ax)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(x = 'deck', kind = 'count', palette = 'ch:0.95', data = titanic, hue = 'class')

# %% [markdown]
# ### 3. Visualizing Distribution of the Data
# - distplot()
# - kdeplot()
# - jointplot()
# - rugplot()

# %% [markdown]
# ### i)  displot():
# * This function combines the matplotlib ``hist`` function (with automatic calculation of a good default bin size) with the seaborn :func:`kdeplot` and :func:`rugplot` functions. It can also fit ``scipy.stats``distributions and plot the estimated PDF over the data.

# %%
from numpy.random import randn
x = randn(100)

# %%
# x is nothing but the dataset, kde(Kernal density estimation): The curve which is created is actually kde.

sns.distplot(x, kde = True, hist = True, rug= False, bins= 30)
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# In order to check how 'Total Bill' in tips DataSet is distributed 

sns.distplot(tips['total_bill'], kde = True, hist = True, rug= False, bins= 30)
# So our total_bill plot is something like this as below:
# we can conclude that maximum bill given in range of amount 10-30 Rupees.
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ### ii) JointPlot(): Draw a plot of two variables with bivariate and univariate graphs.
#
# This function provides a convenient interface to the :class:`JointGrid`
# class, with several canned plot kinds. This is intended to be a fairly
# lightweight wrapper; if you need more flexibility, you should use
# :class:`JointGrid` directly.

# %%
x = tips['total_bill']
y = tips['tip']

# %%
sns.jointplot(x = x, y=y)

# %%
# Using kind parameter we can draw different different plots:
# kind : { "scatter" | "kde" | "hist" | "hex" | "reg" | "resid" }

# kind = 'hex'

sns.set() # it is setting the background thing.

sns.jointplot(x = x, y=y, kind = 'hex')

# more dense color due to more density of points at that area. As the density decreases color becomes light.

# %%
# kind = 'kde'
# If you see in this plot there is circle which is telling that similar density points are joined.

# %%
sns.jointplot(x = x, y = y, kind = 'kde')

# %%
# Kind=hist
sns.jointplot(x = x, y = y, kind = 'hist')

# %% [markdown]
# ### ii) kdeplot():
#
# * Plot univariate or bivariate distributions using kernel density estimation.
#
# * A kernel density estimate (KDE) plot is a method for visualizing the distribution of observations in a dataset, analagous to a histogram. KDE represents the data using a continuous probability density curve in one or more dimensions.
#
# * The approach is explained further in the :ref:`user guide <tutorial_kde>`.
#
# * Relative to a histogram, KDE can produce a plot that is less cluttered and more interpretable, especially when drawing multiple distributions. But it has the potential to introduce distortions if the underlying distribution is bounded or not smooth. Like a histogram, the quality of the representation also depends on the selection of good smoothing parameters.

# %%
x  # x is total_bill
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
y # y is tip.
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
# Creating subplots gives two things:<Figure size 432x432 with 1 Axes>, <AxesSubplot:>
# One is figure i.e. the entire figure and 
# second value is wrt to the subplots that u r creating u will be able access plots where u plot the things.

# we are creating f variable for entire figure
# and ax for Axes (ie. second value)

import matplotlib.pyplot as plt
plt.subplots(figsize = (6,6))
# Out:
# (<Figure size 432x432 with 1 Axes>, <AxesSubplot:>)

# %%
f, ax = plt.subplots(figsize = (6,6))
cmap = sns.cubehelix_palette(as_cmap = True, dark = 0, light = 1, reverse= True)
sns.kdeplot(x, y, cmap = cmap, n_levels=60, shade=True)
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### iii) jointplot():
#
# Draw a plot of two variables with bivariate and univariate graphs.
#
# This function provides a convenient interface to the :class:`JointGrid`
# class, with several canned plot kinds. This is intended to be a fairly
# lightweight wrapper; if you need more flexibility, you should use
# :class:`JointGrid` directly.

# %%
g = sns.jointplot(x, y, kind = 'kde', color = 'r')
g
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# plot_joint(): Draw a bivariate plot on the joint axes of the grid.

g = sns.jointplot(x, y, kind = 'kde', color = 'r')
g.plot_joint(plt.scatter, c = 'b', s = 30, linewidth = 1, marker = '+')
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
## alpha is for transparancy, suppose if I want outer ring to be dim light them lets say i set_alpha=0.2:
g = sns.jointplot(x, y, kind = 'kde', color = 'r')
g.plot_joint(plt.scatter, c = 'b', s = 30, linewidth = 1, marker = '+')

g.ax_joint.collections[0].set_alpha(0.2)
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
## suppose if I want second outer ring to be dim light them lets say i set_alpha=0.2:
# So, I will take g.ax_joint.collections[1]:

g = sns.jointplot(x, y, kind = 'kde', color = 'r')
g.plot_joint(plt.scatter, c = 'b', s = 30, linewidth = 1, marker = '+')

g.ax_joint.collections[1].set_alpha(0.2)
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### pairplot:
# Plot pairwise relationships in a dataset. It does not take categorical features.
#
# * For eg, in iris DataSet

# %%
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris)

# We can find out relationship among all features.
# Why is sepal length is in bar chart ? 
# Not just sepal length whenever u compare with same feature as here sepal length with sepal length u get bar chart.

# %%
sns.pairplot(iris,hue='species')


## I'm using categorical features to plot the points:
# If i want to get species setosa then I can observe from graph that if petal length<2.
# So u can get observations from these plots.

# %% [markdown]
# ### PairGrid:
# Subplot grid for plotting pairwise relationships in a dataset.
#
# This object maps each variable in a dataset onto a column and row in a
# grid of multiple axes. Different axes-level plotting functions can be
# used to draw bivariate plots in the upper and lower triangles, and the
# the marginal distribution of each variable can be shown on the diagonal.

# %%
g = sns.PairGrid(iris)

## It will just give just the relationship with all features but inside this what is to be ploted will be done by map_diag.

# %%
# map_diag: Plot with a univariate function on each diagonal subplot.
# map_diag is nothing but basically says what kind of u want to apply. Suppose I say kdeplot then see the code:
# map_offdiag: Plot with a bivariate function on the off-diagonal subplots.

g = sns.PairGrid(iris)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot, n_levels = 10)

# %% [markdown]
# ### 4. Linear Regression and Relationship
# - regplot()
# - lmplot()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
## lmplot():Plot data and regression model fits across a FacetGrid. It is going to find out best fit line for specific data

# %%
sns.lmplot(x = 'total_bill', y= 'tip', data = tips)

# %% [markdown]
# ### regplot:
# Plot data and a linear regression model fit.
#
# There are a number of mutually exclusive options for estimating the
# regression model. See the :ref:`tutorial <regression_tutorial>` for more
# information.

# %%
f, ax = plt.subplots(figsize = (8,4))
sns.regplot(x = 'total_bill', y = 'tip', data = tips, ax = ax)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tips, col = 'day', col_wrap=2, height = 4)

# %% [markdown]
# ### 5. Controlling Ploted Figure Aesthetics
# - figure styling
# - axes styling
# - color palettes
# - etc..

# %%
def sinplot():
    x = np.linspace(0, 14, 100)
    for i in range(1, 5):
        plt.plot(x, np.sin(x+i*0.5)*(7-i))

# %%
import numpy as np
sinplot()

# %%
sns.set_style('ticks', {'axes.grid': True, 'xtick.direction': 'in'})
sinplot()
sns.despine(left = True, bottom= False)

# %%
sns.axes_style()
# Out:
# {'axes.facecolor': 'white',
#  'axes.edgecolor': '.15',
#  'axes.grid': True,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': '.8',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'in',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': 'round',
#  'patch.edgecolor': 'w',
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'patch.force_edgecolor': True,
#  'xtick.bottom': True,
#  'xtick.top': False,
#  'ytick.left': True,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %%
sns.set_style('darkgrid')

# %%
sns.set_context('talk', font_scale=1.5)
sinplot()

# %%
current_palettes = sns.color_palette()
sns.palplot(current_palettes)

# %%
sns.palplot(sns.color_palette('hls', 8))
