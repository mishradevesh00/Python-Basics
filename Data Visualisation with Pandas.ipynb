# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
np.random.randint(0,100,3) ## It will always give o/p in form of array.
# Out:
# array([65, 84, 32])

# %%
from numpy.random import randn,rand, randint, uniform, sample

# %%
randn(10) ## It will give those many random numbers given as parameter.(randn gives -ve numbers also)
          ## i.e. It is array of 10 random numbers.
# Out:
# array([ 0.83853714,  2.27480289,  1.31937973, -0.46290573,  0.7222006 ,
#         0.66962035, -1.53511735, -1.57865665, -1.20917082,  1.06721298])

# %%
rand(10) ## rand gives positive random numbers only.
# Out:
# array([0.70977377, 0.71558624, 0.51970321, 0.41489113, 0.2682185 ,
#        0.34690783, 0.53957886, 0.87766778, 0.18943636, 0.6831386 ])

# %% [markdown]
# ### cumulative sum : cumsum()

# %%
s=pd.Series([1,2,np.nan,-1,0])
s.cumsum()
# Out:
# 0    1.0
# 1    3.0
# 2    NaN
# 3    2.0
# 4    2.0
# dtype: float64

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range('2019-06-07', periods = 1000), columns=['value'])
ts = pd.Series(randn(1000), index = pd.date_range('2019-06-07', periods = 1000))
df.head()
# Out:
#                value
# 2019-06-07  1.277219
# 2019-06-08  0.023917
# 2019-06-09 -0.177118
# 2019-06-10  0.493254
# 2019-06-11  1.068746

# %%
print(type(df))
print(type(ts))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
ts.head()
# Out:
# 2019-06-07   -0.767933
# 2019-06-08   -0.394571
# 2019-06-09   -0.603177
# 2019-06-10    0.886898
# 2019-06-11   -0.490768
# Freq: D, dtype: float64

# %% [markdown]
# ### .plot()
#
# Now if I want to plot this above series value i will use ts.plot(),
# As ts is a dataframe or series you can see here and plot() is an inbuilt function, So inside DataFrame I'm using this matplotlib functionality for that we have to import matplotlib.
#
# inside that plot() we are giving figsize(5,5) .
# figsize: a tuple (width, height) in inches

# %%
ts.plot(figsize=(5,5)) ## with help of Series functionality we are plotting this
# Out:
# <AxesSubplot:>

# %%
ts.plot(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### matplotlib plotting :

# %%
plt.plot(ts) ## with the help of matplotlib we are plotting this

# %%
## Simple plotting

x=[1,2,3,4,5]
y=[3,4,5,6,7]

plt.plot(x,y)

# %%
plt.plot(x,y,'r--')

# %%
plt.plot(x,y,'r*')

# %%
plt.plot(x,y,'r--*')

# %%
plt.plot(x,y,'r--')
plt.title("This is a demo graph")
# Out:
# Text(0.5, 1.0, 'This is a demo graph')

# %%
df['value'] = df['value'].cumsum()
df.head()
# Out:
#                value
# 2019-06-07  1.277219
# 2019-06-08  1.301136
# 2019-06-09  1.124018
# 2019-06-10  1.617272
# 2019-06-11  2.686018

# %%
ts = ts.cumsum()
ts.head()
# Out:
# 2019-06-07   -0.767933
# 2019-06-08   -1.162504
# 2019-06-09   -1.765680
# 2019-06-10   -0.878782
# 2019-06-11   -1.369550
# Freq: D, dtype: float64

# %%
type(df), type(ts)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
ts.plot(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
plt.plot(ts)

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Using Seaborn library

# %%
import seaborn as sns

# %%
## Opening iris Dataset.

iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
## To see unique species names:

iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %% [markdown]
# ### Plotting Techniques in Pandas:

# %%
# Plotting iris data sets.

ax = iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
tips=sns.load_dataset('tips')

# %%
## Plotting tips dataset:

ax = tips.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
# We have created a Series named ts:
ts.head()
# Out:
# 2019-06-07   -0.767933
# 2019-06-08   -1.162504
# 2019-06-09   -1.765680
# 2019-06-10   -0.878782
# 2019-06-11   -1.369550
# Freq: D, dtype: float64

# %%
ts.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
## With iris dataset if we want to plot in bar of horizontal kind:
iris.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
# As species column is not in numeric value therefore dropping that column

df = iris.drop(['species'], axis = 1)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
# iloc[0] will give first row values.

df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
# Plotting the first row values in bar format:

df.iloc[0].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# We can do the same plotting as above ie. plotting bar graph using plot.bar()

df.iloc[0].plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Let's Load the titatic Dataset:

titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# plotting passenger class column only in bar form:

titanic['pclass'].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
# Creating a new DataFrame:

df = pd.DataFrame(randn(10, 4), columns=['a', 'b', 'c', 'd'])
df.head(10)
# Out:
#           a         b         c         d
# 0 -0.808830  0.036879 -1.232775 -0.970372
# 1  1.134461 -1.610193  0.611642  0.597337
# 2 -1.538988 -0.392264 -1.167817 -0.332833
# 3  0.004993 -1.359946 -0.312781  2.507553
# 4 -0.482971  1.283719 -0.416242  0.923470
# 5 -0.887694  2.344280  2.016970  0.526292
# 6 -1.909151  0.163602 -0.310991  1.303005
# 7 -1.248986 -1.370824 -1.266302 -0.848157
# 8  0.522476  0.631468  0.203896  0.197628
# 9 -0.589833 -0.404792  0.685849  0.936286

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df.plot.barh()
# Out:
# <AxesSubplot:>

# %%
iris.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
## Stacked Parameter:


iris.plot(kind = 'hist', stacked = False, bins = 100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = 'hist', stacked = True, bins = 50, orientation = 'horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
## Opening the sepal_width column in iris dataset:

iris['sepal_width']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
# To find out rolling difference :

iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind = 'hist', stacked = True, bins = 50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
## We can also do this diff() opration on entire datset:

# %%
df = iris.drop(['species'], axis = 1)
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
# We can create histogram of above o/p obtained after prforming diff operation:
# alpha is for transparancy ranging between 0(min transparancy) to 1(max transparancy).

df.diff().hist(color = 'b', alpha = 0.1, figsize=(10,10))

## bcs df has four feature thus for every feature graph will be plot.
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df.diff().hist(color = 'b', alpha = 1, figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
# Scatter Plot:

df.plot.scatter(x = 'sepal_length', y = 'petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
# Inplace of giving color as c='g' or something we can also give color as:  c = 'sepal_width'
# And based on the range of values in  c = 'sepal_width' the colour will be decided.

df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length');
#df.plot.scatter(x = 'sepal_width', y = 'petal_width', label = 'Width', ax = ax, color = 'r')
#df.plot.scatter(x = 'sepal_width', y = 'petal_length', label = 'Width', ax = ax, color = 'g')

# %%
# using solid i.e. s parameter: s is basically solid pixels.

df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 190)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
## Plotting hexbin kind of plot:

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 5, C = 'sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
## Pie Plot:

# %%
d = df.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize = (5,5))
# Out:
# <AxesSubplot:ylabel='0'>

# %%
df.head(3) # means we can see only 3 records
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2

# %%
# For transpose we use .T :

d = df.head(3).T

# %%
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots = True, figsize = (20, 20))
# As here are 3 column values in Transpose form thus 3 plots will be formed.
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
d.plot.pie(subplots = True, figsize = (20, 20), fontsize = 16, autopct = '%.2f')
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
[0.1]*4
# Out:
# [0.1, 0.1, 0.1, 0.1]

# %%
series = pd.Series([0.2]*5, index = ['a','b','c', 'd','e'], name = 'Pie Plot')
series.plot.pie()
# Out:
# <AxesSubplot:ylabel='Pie Plot'>

# %%
## Don't bother right now about these below are parts of statistical analysis we will see in that.

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df, figsize= (8,8), diagonal='kde', color = 'b')
plt.show()

# %%
ts.plot.kde()

# %%
from pandas.plotting import andrews_curves

# %%
andrews_curves(df, 'sepal_width')

# %%
ts.plot(style = 'r--', label = 'Series', legend = True)

# %%
df.plot(legend = True, figsize = (10, 5), logy = True)

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width]
# Index: []

# %%
x = df.drop(['sepal_width', 'petal_width'], axis = 1)
x.head()
# Out:
#    sepal_length  petal_length
# 0           5.1           1.4
# 1           4.9           1.4
# 2           4.7           1.3
# 3           4.6           1.5
# 4           5.0           1.4

# %%
y = df.drop(['sepal_length', 'petal_length'], axis = 1)
y.head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
ax = x.plot()
y.plot(figsize = (16,10), secondary_y=True, ax = ax)

# %%
x.plot(figsize=(10,5), x_compat = True)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
## if we set subplots = True then each features will be plotting in separate plots.

df.plot(subplots = True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
# layout is basically says that how many rows and columns you want in plot:

df.plot(subplots = True, sharex = False, layout = (2,3), figsize = (16,8))
plt.tight_layout()

# %%
## We will see it later:

# %%
from descartes import PolygonPatch

# %%
map_df = gpd.read_file("London_Borough_Excluding_MHW.shp")
# check data type so we can see that this is not a normal dataframe, but a GEOdataframe
map_df.head()
map_df.plot()

# %%
import geopandas as gpd

# %%
map_df
# Out:
#                       NAME   GSS_CODE   HECTARES  NONLD_AREA ONS_INNER  \
# 0     Kingston upon Thames  E09000021   3726.117       0.000         F
# 1                  Croydon  E09000008   8649.441       0.000         F
# 2                  Bromley  E09000006  15013.487       0.000         F
# 3                 Hounslow  E09000018   5658.541      60.755         F
# 4                   Ealing  E09000009   5554.428       0.000         F
# 5                 Havering  E09000016  11445.735     210.763         F
# 6               Hillingdon  E09000017  11570.063       0.000         F
# 7                   Harrow  E09000015   5046.330       0.000         F
# 8                    Brent  E09000005   4323.270       0.000         F
# 9                   Barnet  E09000003   8674.837       0.000         F
# 10                 Lambeth  E09000022   2724.940      43.927         T
# 11               Southwark  E09000028   2991.340     105.139         T
# ...
